# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavanipothuraju/FMML-LAB1/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 06:10:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   130MB/s    in 0.5s
#
# 2024-03-25 06:10:35 (130 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30477  1712.02976v1  Neural networks are vulnerable to adversarial ...    cs
# 31931   1301.2609v5  This paper considers the use of a simple poste...    cs
# 7210   1711.01514v1  Preserving the privacy of individuals by prote...  stat
# 22198  1507.05117v1  Approximate Bayesian computation (ABC) using a...  stat
# 26756  1611.08091v1  Deep models have achieved impressive performan...    cs
# ...             ...                                                ...   ...
# 29972  1711.03278v1  Convolution Neural Networks (CNN), known as Co...    cs
# 319     1406.2602v1  We consider the problem of learning from a sim...  stat
# 40564   1308.1066v1  Adaptive trials are now mainstream science. Re...  stat
# 23509   1304.0019v1  This work presents an automatic human gender a...    cs
# 27866  1704.07595v1  Current state-of-the-art approaches to skeleto...    cs
#
#                                                    title  year  \
# 30477  Defense against Adversarial Attacks Using High...  2017
# 31931        Learning to Optimize Via Posterior Sampling  2013
# 7210                 Distribution-Preserving k-Anonymity  2017
# 22198  Fast Approximate Bayesian Computation for Esti...  2015
# 26756      Deep Joint Face Hallucination and Recognition  2016
# ...                                                  ...   ...
# 29972  Feed Forward and Backward Run in Deep Convolut...  2017
# 319       Graph Approximation and Clustering on a Budget  2014
# 40564  Theoretical Issues for Global Cumulative Treat...  2013
# 23509  Age group and gender recognition from human fa...  2013
# 27866  Skeleton-based Action Recognition with Convolu...  2017
#
#                                                 keywords
# 30477  [vulnerable, adversarial, phenomenon, applicat...
# 31931  [considers, posterior, algorithm, exploration,...
# 7210   [preserving, individuals, protecting, sensitiv...
# 22198  [approximate, computation, sequential, compreh...
# 26756  [impressive, performance, hallucination, hallu...
# ...                                                  ...
# 29972  [convolution, application, classification, rec...
# 319    [similarity, clustering, imensional, computing...
# 40564  [mainstream, researchers, conclusion, proposin...
# 23509  [automatic, recognition, extensive, experiment...
# 27866  [approaches, recognition, recurrent, convoluti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30477    [vulnerable, adversarial, phenomenon, applicat...
# 31931    [considers, posterior, algorithm, exploration,...
# 7210     [preserving, individuals, protecting, sensitiv...
# 22198    [approximate, computation, sequential, compreh...
# 26756    [impressive, performance, hallucination, hallu...
#                                ...
# 7308     [autoregressive, estimators, likelihoods, gene...
# 9539     [addresses, misalignments, variations, identif...
# 10939    [introduce, multivariate, equivalent, inferenc...
# 5391     [processes, parameter, uncertainty, uncertaint...
# 11246    [appealing, flexibility, capturing, uncertaint...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8785 words.
# Out of those 4578 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4dbec8a0-81e7-4538-a27b-f19613393e3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dbec8a0-81e7-4538-a27b-f19613393e3f")) {                    Plotly.newPlot(                        "4dbec8a0-81e7-4538-a27b-f19613393e3f",                        [{"x":["advantages","information","sensitive","defending","applications","adversarial","techniques","preprocessing","validated","transferred","important","robustness","suppressing","structure","traditional","representation","influence","effective","phenomenon","activated","strengthen","difference","vulnerable","classification","generalizes","specialized","highlighted","algorithm","establishes","considers","surpassing","significant","exploitation","demonstrate","dependence","dimension","available","connection","complicated","generalized","performance","developed","confidence","posterior","exploration","contribution","contributions","theoretical","simulation","algorithms","relationships","clustering","attributes","individuals","quantifying","probability","experiments","quantization","extensive","dithering","preservation","variables","principles","insurance","furthermore","empirically","consideration","workloads","preserving","anonymity","understand","respectively","covariate","distribution","framework","specialize","necessary","identifier","approaches","application","comparably","inference","equations","processes","generated","estimating","execution","comprehensive","computational","observations","requirement","synthetic","sequential","selection","derivatives","approximate","estimated","integration","computation","sensitivity","estimation","estimates","comparing","significantly","described","numerical","parameter","circumventing","parameters","biological","differential","particular","outperforming","extensively","recognition","conventional","verification","discriminative","minimizing","experimental","representations","producing","visualization","challenging","convolution","impressive","hallucinated","responsible","statistical","widespread","nesterovs","optimization","stochastic","accelerating","acceleration","conjugate","effectively","designing","accelerated","sentiment","accumulation","approximation","instability","regression","characterization","introduces","independent","manufactured","comparable","different","riemannian","microscope","efficient","diagnostic","facilitates","detection","infectious","unsupervised","dimensional","considered","component","consuming","conditions","worldwide","identification","intervention","supervised","currently","microscopy","inaccurate","diagnosis","describes","substantial","canonical","solutions","decomposition","principal","embedding","correlation","regularized","integrate","promoting","optimally","regularization","achieving","subproblem","formulation","multilingual","constrained","judiciously","incorporating","negativity","processing","compounds","components","multiview","constraints","scalability","alternates","converges"],"y":[84,667,61,3,430,95,380,24,40,12,348,109,3,327,190,372,62,243,19,4,3,69,17,516,29,22,11,851,9,25,9,245,23,557,25,75,284,44,24,74,875,189,41,44,55,74,49,156,74,588,62,153,68,48,19,178,605,14,181,1,5,148,40,1,153,79,20,2,43,1,68,91,2,229,517,2,71,7,426,263,6,209,23,103,171,54,24,83,259,86,35,133,67,130,10,105,53,45,158,32,201,76,64,277,63,81,112,2,217,42,26,272,36,45,370,102,32,83,49,358,250,31,34,254,47,23,2,9,154,10,2,312,124,16,18,9,111,48,16,51,5,124,11,123,26,72,134,1,91,748,9,2,396,15,13,367,3,145,206,150,97,33,144,12,86,10,205,48,13,8,51,83,47,11,141,53,26,105,66,45,40,5,11,84,71,3,85,17,58,0,65,3,304,1,109,2,138,43,5,25],"type":"bar"},{"x":["advantages","information","sensitive","defending","applications","adv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4578,), (4578, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Breast</span> <span style=''>Cancer</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Histology</span> <span style=''>using</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Breast</span> <span style=''>Cancer</span> <span style=''>is</span> <span style=''>a</span> <span style=''>major</span> <span style=''>cause</span> <span style=''>of</span> <span style=''>death</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538461);'>worldwide</span> <span style=''>among</span> <span style=''>women</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Hematoxylin</span> <span style=''>and</span> <span style=''>Eosin</span> <span style=''>(HE)</span> <span style=''>stained</span> <span style=''>breast</span> <span style=''>tissue</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>biopsies</span> <span style=''>are</span> <span style=''>observed</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>microscopes</span> <span style=''>for</span> <span style=''>the</span> <span style=''>primary</span> <span style='background-color:rgba(0, 255, 0, 0.5692307692307692);'>diagnosis</span> <span style=''>of</span> <span style=''>breast</span> <span style=''>cancer</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>HE</span> <span style=''>stained</span> <span style=''>breast</span> <span style=''>tissue</span> <span style=''>images</span> <span style=''>released</span> <span style=''>for</span> <span style=''>BACH</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>2018</span> <span style=''>by</span> <span style=''>fine</span> <span style=''>tuning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inception</span> <span style=''>v3</span> <span style='background-color:rgba(0, 255, 0, 0.592274678111588);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Szegedy</span> <span style=''>et</span> <span style=''>al</span> <span style=''>These</span> <span style=''>images</span> <span style=''>are</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>classified</span> <span style=''>into</span> <span style=''>four</span> <span style=''>classes</span> <span style=''>namely</span> <span style=''>i)</span> <span style=''>normal</span> <span style=''>tissue</span> <span style=''>ii)</span> <span style=''>benign</span> <span style=''>tumor</span> <span style=''>iii)</span> <span style=''>in</span> <span style=''>situ</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>carcinoma</span> <span style=''>and</span> <span style=''>iv)</span> <span style=''>invasive</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>carcinoma</span> <span style=''>Our</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>patches</span> <span style=''>based</span> <span style=''>on</span> <span style=''>nuclei</span> <span style=''>density</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>random</span> <span style=''>or</span> <span style=''>grid</span> <span style=''>sampling</span> <span style=''>along</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rejection</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimizing</span> <span style=''>the</span> <span style=''>CVaR</span> <span style=''>via</span> <span style=''>Sampling</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Value</span> <span style=''>at</span> <span style=''>Risk</span> <span style=''>(CVaR)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominent</span> <span style=''>risk</span> <span style=''>measure</span> <span style=''>that</span> <span style=''>is</span> <span style=''>being</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>in</span> <span style=''>various</span> <span style=''>domains</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>formula</span> <span style=''>for</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CVaR</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style=''>formula</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>sampling</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>the</span> <span style=''>CVaR</span> <span style=''>gradient</span> <span style=''>in</span> <span style=''>the</span> <span style=''>spirit</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style=''>method</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>a</span> <span style=''>local</span> <span style=''>CVaR</span> <span style=''>optimum</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>consider</span> <span style=''>CVaR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>in</span> <span style=''>new</span> <span style=''>domains</span> <span style=''>As</span> <span style=''>an</span> <span style=''>example</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>and</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>controller</span> <span style=''>for</span> <span style=''>the</span> <span style=''>game</span> <span style=''>of</span> <span style=''>Tetris</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Gibbs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>from</span> <span style=''>GA</span> <span style=''>dynamics</span> <br/><br/><span style=''>A</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>of</span> <span style=''>average</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.403409090909091);'>evaluation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>dynamics</span> <span style=''>such</span> <span style=''>as</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>(GAs)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>and</span> <span style=''>its</span> <span style=''>validity</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3157894736842105);'>numerically</span> <span style=''>examined</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>of</span> <span style=''>Gibbs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>from</span> <span style=''>training</span> <span style=''>sets</span> <span style=''>which</span> <span style=''>are</span> <span style=''>gene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>configurations</span> <span style=''>(strings)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>GA</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>figure</span> <span style=''>out</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3155555555555556);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>GA</span> <span style=''>from</span> <span style=''>the</span> <span style=''>view</span> <span style=''>point</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333335);'>thermodynamics</span> <span style=''>The</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3136094674556213);'>minimization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Kullback</span> <span style=''>Leibler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>between</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.390728476821192);'>parametric</span> <span style=''>Gibbs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>gene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>configurations</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style=''>solvable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sequence</span> <span style=''>Modeling</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Segmentations</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Segmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>a</span> <span style=''>common</span> <span style=''>pattern</span> <span style=''>in</span> <span style=''>many</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>such</span> <span style=''>as</span> <span style=''>phrases</span> <span style=''>in</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>via</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmented</span> <span style=''>sequence</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>as</span> <span style=''>the</span> <span style=''>product</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>all</span> <span style=''>its</span> <span style=''>segments</span> <span style=''>where</span> <span style=''>each</span> <span style=''>segment</span> <span style=''>is</span> <span style=''>modeled</span> <span style=''>using</span> <span style=''>existing</span> <span style=''>tools</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Since</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>unknown</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>we</span> <span style=''>sum</span> <span style=''>over</span> <span style=''>all</span> <span style=''>valid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentations</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>forward</span> <span style=''>and</span> <span style=''>backward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resorting</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>We</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09061719586157688)
# 	information (0.23795932929004637)
# 	representation (0.13271494826971103)
# 	architecture (0.09133071708883339)
# 	segmentation (0.07420620763467713)
# 	processing (0.10845522654298966)
# 	different (0.2668569389939351)
# 	detection (0.13093114520156976)
# 	convolutional (0.13235818765608276)
# 	recognition (0.13200142704245452)
#
# Some Statistics words are:
# 	convergence (0.12318477716574862)
# 	variables (0.13820731096644967)
# 	estimation (0.16174261392088132)
# 	statistical (0.14822233350025038)
# 	distribution (0.18327491236855284)
# 	algorithm (0.40610916374561845)
# 	theoretical (0.1597396094141212)
# 	dimensional (0.18577866800200302)
# 	inference (0.19879819729594392)
# 	regression (0.18778167250876315)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5470df85-ff1f-459b-b22c-675cf2be58f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5470df85-ff1f-459b-b22c-675cf2be58f9")) {                    Plotly.newPlot(                        "5470df85-ff1f-459b-b22c-675cf2be58f9",                        [{"x":["advantages","information","sensitive","defending","applications","adversarial","techniques","preprocessing","validated","transferred","important","robustness","suppressing","structure","traditional","representation","influence","effective","phenomenon","activated","strengthen","difference","vulnerable","classification","generalizes","specialized","highlighted","algorithm","establishes","considers","surpassing","significant","exploitation","demonstrate","dependence","dimension","available","connection","complicated","generalized","performance","developed","confidence","posterior","exploration","contribution","contributions","theoretical","simulation","algorithms","relationships","clustering","attributes","individuals","quantifying","probability","experiments","quantization","extensive","dithering","preservation","variables","principles","insurance","furthermore","empirically","consideration","workloads","preserving","anonymity","understand","respectively","covariate","distribution","framework","specialize","necessary","identifier","approaches","application","comparably","inference","equations","processes","generated","estimating","execution","comprehensive","computational","observations","requirement","synthetic","sequential","selection","derivatives","approximate","estimated","integration","computation","sensitivity","estimation","estimates","comparing","significantly","described","numerical","parameter","circumventing","parameters","biological","differential","particular","outperforming","extensively","recognition","conventional","verification","discriminative","minimizing","experimental","representations","producing","visualization","challenging","convolution","impressive","hallucinated","responsible","statistical","widespread","nesterovs","optimization","stochastic","accelerating","acceleration","conjugate","effectively","designing","accelerated","sentiment","accumulation","approximation","instability","regression","characterization","introduces","independent","manufactured","comparable","different","riemannian","microscope","efficient","diagnostic","facilitates","detection","infectious","unsupervised","dimensional","considered","component","consuming","conditions","worldwide","identification","intervention","supervised","currently","microscopy","inaccurate","diagnosis","describes","substantial","canonical","solutions","decomposition","principal","embedding","correlation","regularized","integrate","promoting","optimally","regularization","achieving","subproblem","formulation","multilingual","constrained","judiciously","incorporating","negativity","processing","compounds","components","multiview","constraints","scalability","alternates","converges","pertinent","effectiveness","simulations","alternating","structural","sublinear","reconstruction","underlying","exploiting","hierarchical","likelihoods","generative","systematically","objective","principle","combining","variational","distributions","discriminators","quantitatively","discriminates","likelihood","tractable","univariate","movements","stationary","stationarity","generalization","predicting","complexity","minimization","autoregressive","instances","correspondence","motivated","assumptions","consequences","perturbed","stability","examination","interesting","resilient","multiplicative","sometimes","objectives","perturbations","distances","resilience","introduced","frequency","deformable","microwave","circumstan ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	judiciously
# 	invertibility
# 	overdetermined
# 	heckerman
# 	inverting
# 	sharpness
# 	marginalizing
# 	catalogue
# 	homomorphic
# 	undesired
# 	triangular
# 	disentanglement
# 	purchases
# 	lancaster
# 	debiasing
# 	inpatient
# 	administrative
# 	determinants
# 	independencies
# 	unmeasured
# Some words which never appear in Statistics papers:
# 	defending
# 	surpassing
# 	hallucinated
# 	pedestrian
# 	characterisations
# 	strategic
# 	transducers
# 	linguistics
# 	certification
# 	isabellehol
# 	trustworthiness
# 	determinism
# 	articulated
# 	organisms
# 	montezumas
# 	stagnation
# 	neighbourhoods
# 	consecutively
# 	abstracted
# 	dissemination

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0667320902845925e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
